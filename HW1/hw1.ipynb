# %% [markdown]
# # **作業流程**
#
# 1. 搭建model
#   * 使用MNIST數據集
#   * 設定不同hyperparameters的condition，可以使用的組合：
#     * Activation_settings=["tanh","ReLU"]
#     * Initial_settings=["random","Xavier","Kaiming"]
#     * L2_settings=[0.001,0.0001,"none"]
#     * Optimizer_settings=["sgd","Momentum","Adam"]
#     * epochs_settings=[100,200,300]
#     * hidden_nodes=[5,8,11]
#     * LR_scheduler_settings=["none","cosine"]
#
# 2. 訓練model和evaluate
#   * 總共訓練了(3*3*3*2)54種組合：
#     * Activation_settings="ReLU"
#     * Initial_settings=["random","Xavier","Kaiming"]
#     * L2_settings=0.001
#     * Optimizer_settings="Adam"
#     * epochs_settings=[100,200,300]
#     * hidden_nodes=[5,8,11]
#     * LR_scheduler_settings=["none","cosine"]
#
# 3. ensemble 3 top model:
#   * save : 一個dictionary，key為model名稱，value為準確度
#   * 使用save挑出三個準確度最高的model，並且平均三者的predict，再計算出最終的accuracy

# %% [markdown]
# ## 搭建model

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split
Activation_settings=["tanh","ReLU"]
Initial_settings=["random","Xavier","Kaiming"]
L2_settings=[0.001,0.0001,"none"]
Optimizer_settings=["sgd","Momentum","Adam"]
epochs_settings=[100,200,300]
hidden_nodes=[5,8,11]
LR_scheduler_settings=["none","cosine"]
save={}
# 轉換訓練資料
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.1307,), (0.3081,))])

# 載入MNIST手寫數字資料集，並將資料轉換為Tensor型態
train_data = torchvision.datasets.MNIST(root='./data', train=True, 
                                        transform=transform, 
                                        download=True)
test_data = torchvision.datasets.MNIST(root='./data', train=False, 
                                       transform=transform, 
                                       download=True)
dataset = ConcatDataset([train_data, test_data])




train_data, test_data = train_test_split(dataset, random_state=777, train_size=0.8)


batch_size = 64
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)
# Out:
# c:\Users\CGVMISLAB\.conda\envs\FER\lib\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
class TwoLayerNet(torch.nn.Module):

    def __init__(self, Activation_settings, hidden_nodes):
        super(TwoLayerNet, self,).__init__()
        self.fc1 = torch.nn.Linear(28*28, hidden_nodes)
        self.fc2 = torch.nn.Linear(hidden_nodes, 10)
        self.activation = Activation_settings

    def forward(self, x):
      if self.activation =="ReLU":
        x = x.view(-1, 28*28)
        x = torch.nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
      elif self.activation =="tanh":
        x = x.view(-1, 28*28)
        x = torch.nn.functional.tanh(self.fc1(x))
        x = self.fc2(x)
      return x

# %%
def init_weight(m, Initial_settings='Xavier', Activation_settings='none'):
  if isinstance(m,nn.Linear):
    if Initial_settings =='Xavier':
      torch.nn.init.xavier_uniform(m.weight)
    elif Initial_settings =='Kaiming':
      torch.nn.init.kaiming_uniform(m.weight, nonlinearity = Activation_settings)

# %%
def train(Activation_settings, Initial_settings, L2_settings, Optimizer_settings, epochs_settings, hidden_nodes, LR_scheduler_settings):
  model = TwoLayerNet(Activation_settings, hidden_nodes)
  if Initial_settings =='Xavier':
      model.apply(lambda model: init_weight(model, "Xavier"))
  elif Initial_settings =='Kaiming':
      model.apply(lambda model: init_weight(model, "Kaiming", 'relu'))

  if Optimizer_settings =='sgd':
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, weight_decay=L2_settings)
  elif Optimizer_settings =='momentum':
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=L2_settings)
  else:
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=L2_settings)
  
  if LR_scheduler_settings == 'cosine':
    torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 32, eta_min=0, last_epoch=-1)
    
  criterion = torch.nn.CrossEntropyLoss()

  for epoch in range(epochs_settings):
    total=0
    correct=0
    best_acc=0
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):

      inputs,label = data #每次64個
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, label)
      loss.backward()
      optimizer.step()

      # running_loss += loss.item()
      # if i % 100 == 0:    
      #         print('[%d, %5d] loss: %.3f' %
      #               (epoch , i , running_loss / 100))
      #         running_loss = 0.0
    with torch.no_grad():
      for data in test_loader:
          images, labels = data
          outputs = model(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          #print("label size", labels.size(0))
          correct += (predicted == labels).sum().item()
          #print("predicted",predicted)
          #print("labels",labels)
          #print("correct", (predicted == labels).sum().item())
      if (correct/total) > best_acc:
        best_acc=correct / total
        save["{}_{}_{}_{}_{}_{}_{}".format(Activation_settings,Initial_settings, L2_settings, Optimizer_settings, epochs_settings, hidden_nodes, LR_scheduler_settings)]={}
        save["{}_{}_{}_{}_{}_{}_{}".format(Activation_settings,Initial_settings, L2_settings, Optimizer_settings, epochs_settings, hidden_nodes, LR_scheduler_settings)]["model"]=model
        save["{}_{}_{}_{}_{}_{}_{}".format(Activation_settings,Initial_settings, L2_settings, Optimizer_settings, epochs_settings, hidden_nodes, LR_scheduler_settings)]["accuracy"]=best_acc
    if epoch % 10 == 0:
      print('Epoch:%d \n Accuracy of the network on the 14000 test images: %d %%' % (
          epoch,100 * correct / total))
  print('Finished Training')
  print('Best Accuracy of the network on the 14000 test images: %d %%' % (
        100 * best_acc))
  torch.save(model, '{}_{}_{}_{}_{}_{}_{}.pt'.format(Activation_settings,Initial_settings, L2_settings, Optimizer_settings, epochs_settings, hidden_nodes, LR_scheduler_settings))
  print(save)

# %% [markdown]
# ## 訓練model和evaluate

# %%
for i in range(3):
  for e in range(3):
    for h in range(3):
      for lr in range(2):
        train(Activation_settings[1], Initial_settings[i], L2_settings[0], Optimizer_settings[2], epochs_settings[e], hidden_nodes[h], LR_scheduler_settings[lr])
# Out:
# Epoch:0
#  Accuracy of the network on the 14000 test images: 79 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 89 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 82 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 89 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 91 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 94 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 91 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 94 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 94 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 76 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 88 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 89 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 83 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 88 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 89 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 88 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 93 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 93 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 91 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 94 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 91 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 94 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 94 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}, 'ReLU_random_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9472857142857143}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 80 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:200
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:210
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:220
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:230
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:240
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:250
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:260
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:270
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:280
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:290
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 90 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}, 'ReLU_random_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9472857142857143}, 'ReLU_random_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9015}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 83 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:200
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:210
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:220
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:230
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:240
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:250
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:260
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:270
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:280
#  Accuracy of the network on the 14000 test images: 90 %
# Epoch:290
#  Accuracy of the network on the 14000 test images: 89 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 90 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}, 'ReLU_random_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9472857142857143}, 'ReLU_random_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9015}, 'ReLU_random_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9025}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 89 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:200
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:210
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:220
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:230
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:240
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:250
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:260
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:270
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:280
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:290
#  Accuracy of the network on the 14000 test images: 93 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 93 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}, 'ReLU_random_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9472857142857143}, 'ReLU_random_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9015}, 'ReLU_random_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9025}, 'ReLU_random_0.001_Adam_300_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9335}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 87 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:200
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:210
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:220
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:230
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:240
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:250
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:260
#  Accuracy of the network on the 14000 test images: 92 %
# Epoch:270
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:280
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:290
#  Accuracy of the network on the 14000 test images: 92 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 92 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ...
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9021428571428571}, 'ReLU_Kaiming_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8992857142857142}, 'ReLU_Kaiming_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9336428571428571}, 'ReLU_Kaiming_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9334285714285714}, 'ReLU_Kaiming_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9492857142857143}, 'ReLU_Kaiming_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9458571428571428}, 'ReLU_Kaiming_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.902}, 'ReLU_Kaiming_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9031428571428571}, 'ReLU_Kaiming_0.001_Adam_300_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9319285714285714}, 'ReLU_Kaiming_0.001_Adam_300_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9338571428571428}, 'ReLU_Kaiming_0.001_Adam_300_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9359285714285714}}
# Epoch:0
#  Accuracy of the network on the 14000 test images: 88 %
# Epoch:10
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:20
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:30
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:40
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:50
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:60
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:70
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:80
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:90
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:100
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:110
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:120
#  Accuracy of the network on the 14000 test images: 93 %
# Epoch:130
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:140
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:150
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:160
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:170
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:180
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:190
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:200
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:210
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:220
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:230
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:240
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:250
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:260
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:270
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:280
#  Accuracy of the network on the 14000 test images: 94 %
# Epoch:290
#  Accuracy of the network on the 14000 test images: 94 %
# Finished Training
# Best Accuracy of the network on the 14000 test images: 94 %
# {'ReLU_random_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8978571428571429}, 'ReLU_random_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8968571428571429}, 'ReLU_random_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.93}, 'ReLU_random_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9373571428571429}, 'ReLU_random_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9385714285714286}, 'ReLU_random_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9412857142857143}, 'ReLU_random_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8945}, 'ReLU_random_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.897}, 'ReLU_random_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9357142857142857}, 'ReLU_random_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327142857142857}, 'ReLU_random_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9394285714285714}, 'ReLU_random_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9472857142857143}, 'ReLU_random_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9015}, 'ReLU_random_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9025}, 'ReLU_random_0.001_Adam_300_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9335}, 'ReLU_random_0.001_Adam_300_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.928}, 'ReLU_random_0.001_Adam_300_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9418571428571428}, 'ReLU_random_0.001_Adam_300_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9401428571428572}, 'ReLU_Xavier_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8969285714285714}, 'ReLU_Xavier_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9004285714285715}, 'ReLU_Xavier_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9239285714285714}, 'ReLU_Xavier_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9271428571428572}, 'ReLU_Xavier_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.946}, 'ReLU_Xavier_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.944}, 'ReLU_Xavier_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9027857142857143}, 'ReLU_Xavier_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8931428571428571}, 'ReLU_Xavier_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9327857142857143}, 'ReLU_Xavier_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9342857142857143}, 'ReLU_Xavier_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9438571428571428}, 'ReLU_Xavier_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9488571428571428}, 'ReLU_Xavier_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9019285714285714}, 'ReLU_Xavier_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8975714285714286}, 'ReLU_Xavier_0.001_Adam_300_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9324285714285714}, 'ReLU_Xavier_0.001_Adam_300_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9349285714285714}, 'ReLU_Xavier_0.001_Adam_300_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9465}, 'ReLU_Xavier_0.001_Adam_300_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.944}, 'ReLU_Kaiming_0.001_Adam_100_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8977142857142857}, 'ReLU_Kaiming_0.001_Adam_100_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8997142857142857}, 'ReLU_Kaiming_0.001_Adam_100_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9348571428571428}, 'ReLU_Kaiming_0.001_Adam_100_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.932}, 'ReLU_Kaiming_0.001_Adam_100_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9414285714285714}, 'ReLU_Kaiming_0.001_Adam_100_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9371428571428572}, 'ReLU_Kaiming_0.001_Adam_200_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9021428571428571}, 'ReLU_Kaiming_0.001_Adam_200_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.8992857142857142}, 'ReLU_Kaiming_0.001_Adam_200_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9336428571428571}, 'ReLU_Kaiming_0.001_Adam_200_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9334285714285714}, 'ReLU_Kaiming_0.001_Adam_200_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9492857142857143}, 'ReLU_Kaiming_0.001_Adam_200_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9458571428571428}, 'ReLU_Kaiming_0.001_Adam_300_5_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.902}, 'ReLU_Kaiming_0.001_Adam_300_5_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# ), 'accuracy': 0.9031428571428571}, 'ReLU_Kaiming_0.001_Adam_300_8_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9319285714285714}, 'ReLU_Kaiming_0.001_Adam_300_8_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=10, bias=True)
# ), 'accuracy': 0.9338571428571428}, 'ReLU_Kaiming_0.001_Adam_300_11_none': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9359285714285714}, 'ReLU_Kaiming_0.001_Adam_300_11_cosine': {'model': TwoLayerNet(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# ), 'accuracy': 0.9434285714285714}}

# %% [markdown]
# ## Ensemble 3 top model

# %%
import pickle

# save dictionary to person_data.pkl file
with open('save.pkl', 'wb') as fp:
    pickle.dump(save, fp)
    print('dictionary saved successfully to file')
# Out:
# dictionary saved successfully to file

# %%
keys=list(save.keys())
accuracy_list=[]
for key in keys:
    accuracy_list.append(save[key]['accuracy'])
index_order=sorted(range(len(accuracy_list)), key=lambda k: accuracy_list[k],reverse=True)
print(keys[index_order[0]])
print(keys[index_order[1]])
print(keys[index_order[2]])
model1 = torch.load('{}.pt'.format(keys[index_order[0]]))
model2 = torch.load('{}.pt'.format(keys[index_order[1]]))
model3 = torch.load('{}.pt'.format(keys[index_order[2]]))
# Out:
# ReLU_Kaiming_0.001_Adam_200_11_none
# ReLU_Xavier_0.001_Adam_200_11_cosine
# ReLU_random_0.001_Adam_200_11_cosine

# %%
correct = 0
total = 0
with torch.no_grad():
  for data in test_loader:
      images, labels = data
      outputs=[]
      for i in range(3):
        if i == 1:
          outputs1 = model1(images)
          outputs1 = nn.Softmax(dim=1)(outputs1)
          outputs.append(outputs1)
        elif i == 1:
          outputs2 = model2(images)
          outputs2 = nn.Softmax(dim=1)(outputs2)
          outputs.append(outputs2)
        else:
          outputs3 = model3(images)
          outputs3 = nn.Softmax(dim=1)(outputs3)
          outputs.append(outputs3)
      outputs = sum(outputs)/3
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      #print("label size", labels.size(0))
      correct += (predicted == labels).sum().item()
      #print("predicted",predicted)
      #print("labels",labels)
      #print("correct", (predicted == labels).sum().item())
  print('Accuracy of the 3 top network on the 14000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the 3 top network on the 14000 test images: 95 %
